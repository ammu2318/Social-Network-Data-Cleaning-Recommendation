# %%
 # Funxtion for loadind the data
def load_data(filename):
    with open(filename,"r") as f:
        data=json.load(f)
    return data

# %%
data = load_data("data.json")
data
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]},
#   {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]},
#   {'id': 3, 'name': 'Rahul', 'friends': [1], 'liked_pages': [101, 103]},
#   {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}],
#  'pages': [{'id': 101, 'name': 'Python Developers'},
#   {'id': 102, 'name': 'Data Science Enthusiasts'},
#   {'id': 103, 'name': 'AI & ML Community'},
#   {'id': 104, 'name': 'Web Dev Hub'}]}

# %%
type(data)
# Out:
# dict

# %%
def display_user(data):
    print("User and their connections \n")
    for users in data['users']:
        print(f" ID : {users['id']}. {users['name']} is connected with : {users['friends']} and liked pages are {users['liked_pages']}")
    for p in data['pages']:
         print (f" Page  no {p['id']}  is {p['name']}")

# %%
display_user(data)
# Out:
# User and their connections
#
#  ID : 1. Amit is connected with : [2, 3] and liked pages are [101]
#  ID : 2. Priya is connected with : [1, 4] and liked pages are [102]
#  ID : 3. Rahul is connected with : [1] and liked pages are [101, 103]
#  ID : 4. Sara is connected with : [2] and liked pages are [104]
#  Page  no 101  is Python Developers
#  Page  no 102  is Data Science Enthusiasts
#  Page  no 103  is AI & ML Community
#  Page  no 104  is Web Dev Hub
